# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([1,2,3])

plt.figure()

plt.subplot(2,2,1)
plt.plot(x)
plt.subplot(2,2,2)
plt.scatter(x,x)
plt.subplot (2, 2, 3)
plt.bar(x,x)
plt.subplot(2,2,4)
plt.hist(x)

plt.show()
